# %% [markdown]
# # Assignment: Ionosphere Data Problem
#
# ### Dataset Description:
#
# This radar data was collected by a system in Goose Bay, Labrador. This system consists of a phased array of 16 high-frequency antennas with a total transmitted power on the order of 6.4 kilowatts. See the paper for more details. The targets were free electrons in the ionosphere. "Good" radar returns are those showing evidence of some type of structure in the ionosphere. "Bad" returns are those that do not; their signals pass through the ionosphere.
#
# Received signals were processed using an autocorrelation function whose arguments are the time of a pulse and the pulse number. There were 17 pulse numbers for the Goose Bay system. Instances in this databse are described by 2 attributes per pulse number, corresponding to the complex values returned by the function resulting from the complex electromagnetic signal.
#
# ### Attribute Information:
#
# - All 34 are continuous
# - The 35th attribute is either "good" or "bad" according to the definition summarized above. This is a binary classification task.
#
#  <br><br>
#
# <table border="1"  cellpadding="6">
# 	<tbody>
#         <tr>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Data Set Characteristics:&nbsp;&nbsp;</b></p></td>
# 		<td><p class="normal">Multivariate</p></td>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Number of Instances:</b></p></td>
# 		<td><p class="normal">351</p></td>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Area:</b></p></td>
# 		<td><p class="normal">Physical</p></td>
#         </tr>
#      </tbody>
#     </table>
# <table border="1" cellpadding="6">
#     <tbody>
#         <tr>
#             <td bgcolor="#DDEEFF"><p class="normal"><b>Attribute Characteristics:</b></p></td>
#             <td><p class="normal">Integer,Real</p></td>
#             <td bgcolor="#DDEEFF"><p class="normal"><b>Number of Attributes:</b></p></td>
#             <td><p class="normal">34</p></td>
#             <td bgcolor="#DDEEFF"><p class="normal"><b>Date Donated</b></p></td>
#             <td><p class="normal">N/A</p></td>
#         </tr>
#      </tbody>
#     </table>
# <table border="1" cellpadding="6">
#     <tbody>
#     <tr>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Associated Tasks:</b></p></td>
# 		<td><p class="normal">Classification</p></td>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Missing Values?</b></p></td>
# 		<td><p class="normal">N/A</p></td>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Number of Web Hits:</b></p></td>
# 		<td><p class="normal">N/A</p></td>
# 	</tr>
#     </tbody>
#     </table>

# %% [markdown]
# ### WORKFLOW :
# - Load Data
# - Check Missing Values ( If Exist ; Fill each record with mean of its feature ) or any usless column.
# - Shuffle the data if needed.
# - Standardized the Input Variables. **Hint**: Centeralized the data
# - Split into 60 and 40 ratio.
# - Encode labels.
# - Model : 1 hidden layers including 16 unit.
# - Compilation Step (Note : Its a Binary problem , select loss , metrics according to it)
# - Train the Model with Epochs (100).
# - If the model gets overfit tune your model by changing the units , No. of layers , epochs , add dropout layer or add Regularizer according to the need .
# - Prediction should be > **92%**
# - Evaluation Step
# - Prediction

# %% [markdown]
# # Load Data:
# [Click Here to Download DataSet](https://github.com/ramsha275/ML_Datasets/blob/main/ionosphere_data.csv)

# %%
import numpy as np
import pandas as pd
import tensorflow as tf

# %%
# Dataset loading
df = pd.read_csv('ionosphere_data.csv', delimiter=',')

# %%
df
# Out:
#      feature1  feature2  feature3  ...  feature33  feature34  label
# 0           1         0   0.99539  ...    0.18641   -0.45300      g
# 1           1         0   1.00000  ...   -0.13738   -0.02447      b
# 2           1         0   1.00000  ...    0.56045   -0.38238      g
# 3           1         0   1.00000  ...   -0.32382    1.00000      b
# 4           1         0   1.00000  ...   -0.04608   -0.65697      g
# ..        ...       ...       ...  ...        ...        ...    ...
# 346         1         0   0.83508  ...    0.90546   -0.04307      g
# 347         1         0   0.95113  ...    0.91483    0.04712      g
# 348         1         0   0.94701  ...    0.92697   -0.00577      g
# 349         1         0   0.90608  ...    0.87403   -0.16243      g
# 350         1         0   0.84710  ...    0.85764   -0.06151      g
#
# [351 rows x 35 columns]

# %%
df.shape
# Out:
# (351, 35)

# %%
df['feature1'].unique()
# Out:
# array([1, 0])

# %%
df['feature2'].unique()
# Out:
# array([0])

# %%
df.drop(df.columns[1], inplace = True, axis = 1)

# %%
df.head()
# Out:
#    feature1  feature3  feature4  ...  feature33  feature34  label
# 0         1   0.99539  -0.05889  ...    0.18641   -0.45300      g
# 1         1   1.00000  -0.18829  ...   -0.13738   -0.02447      b
# 2         1   1.00000  -0.03365  ...    0.56045   -0.38238      g
# 3         1   1.00000  -0.45161  ...   -0.32382    1.00000      b
# 4         1   1.00000  -0.02401  ...   -0.04608   -0.65697      g
#
# [5 rows x 34 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 351 entries, 0 to 350
# Data columns (total 34 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   feature1   351 non-null    int64
#  1   feature3   351 non-null    float64
#  2   feature4   351 non-null    float64
#  3   feature5   351 non-null    float64
#  4   feature6   351 non-null    float64
#  5   feature7   351 non-null    float64
#  6   feature8   351 non-null    float64
#  7   feature9   351 non-null    float64
#  8   feature10  351 non-null    float64
#  9   feature11  351 non-null    float64
#  10  feature12  351 non-null    float64
#  11  feature13  351 non-null    float64
#  12  feature14  351 non-null    float64
#  13  feature15  351 non-null    float64
#  14  feature16  351 non-null    float64
#  15  feature17  351 non-null    float64
#  16  feature18  351 non-null    float64
#  17  feature19  351 non-null    float64
#  18  feature20  351 non-null    float64
#  19  feature21  351 non-null    float64
#  20  feature22  351 non-null    float64
#  21  feature23  351 non-null    float64
#  22  feature24  351 non-null    float64
#  23  feature25  351 non-null    float64
#  24  feature26  351 non-null    float64
#  25  feature27  351 non-null    float64
#  26  feature28  351 non-null    float64
#  27  feature29  351 non-null    float64
#  28  feature30  351 non-null    float64
#  29  feature31  351 non-null    float64
#  30  feature32  351 non-null    float64
#  31  feature33  351 non-null    float64
#  32  feature34  351 non-null    float64
#  33  label      351 non-null    object
# dtypes: float64(32), int64(1), object(1)
# memory usage: 93.4+ KB

# %%
label = {'g': 1, 'b': 0}

# %%
df['label'] = df['label'].map(label)

# %%
df.head()
# Out:
#    feature1  feature3  feature4  ...  feature33  feature34  label
# 0         1   0.99539  -0.05889  ...    0.18641   -0.45300      1
# 1         1   1.00000  -0.18829  ...   -0.13738   -0.02447      0
# 2         1   1.00000  -0.03365  ...    0.56045   -0.38238      1
# 3         1   1.00000  -0.45161  ...   -0.32382    1.00000      0
# 4         1   1.00000  -0.02401  ...   -0.04608   -0.65697      1
#
# [5 rows x 34 columns]

# %%
train_data = df.sample(frac= 0.6, random_state=125)
test_data = df.drop(train_data.index)

# %%
train_data.head()
# Out:
#      feature1  feature3  feature4  ...  feature33  feature34  label
# 270         1   1.00000   0.08013  ...    0.92226   -0.03673      1
# 116         1   1.00000  -0.14754  ...    0.49180   -0.06557      0
# 135         1   0.89706   0.38235  ...   -0.28676   -0.56618      1
# 91          1   0.84557  -0.08580  ...   -0.18494   -0.59867      0
# 100         1   1.00000  -1.00000  ...    0.00000    0.00000      0
#
# [5 rows x 34 columns]

# %%
test_data.head()
# Out:
#     feature1  feature3  feature4  ...  feature33  feature34  label
# 4          1   1.00000  -0.02401  ...   -0.04608   -0.65697      1
# 6          1   0.97588  -0.10602  ...   -0.13832   -0.80975      1
# 7          0   0.00000   0.00000  ...    0.00000    0.00000      0
# 9          1  -0.01864  -0.08459  ...   -0.08208    0.38065      0
# 10         1   1.00000   0.06655  ...    0.22995   -0.89158      1
#
# [5 rows x 34 columns]

# %%
test_label = (test_data.loc[:, test_data.columns == 'label'])
test_data = (test_data.loc[:, test_data.columns != 'label'])

# %%
test_label.shape
# Out:
# (140, 1)

# %%
test_data.shape
# Out:
# (140, 33)

# %%
train_label = (train_data.loc[:, train_data.columns == 'label'])
train_data = (train_data.loc[:, train_data.columns != 'label'])

# %%
train_label.shape
# Out:
# (211, 1)

# %%
train_data.shape
# Out:
# (211, 33)

# %%
train_data = np.array(train_data)
train_label = np.array(train_label)
test_data = np.array(test_data)
test_label = np.array(test_label)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout


model = Sequential()
model.add(Dense(64, activation='relu', input_shape=(train_data.shape[1],)))
model.add(Dropout(0.2))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1,  activation='sigmoid'))

# %%
from tensorflow.keras import optimizers

model.compile(optimizer = 'RMSprop', loss='binary_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(train_data, train_label, validation_split=0.2, epochs=80, batch_size = 16)
# Out:
# Epoch 1/80
# 11/11 [==============================] - 1s 19ms/step - loss: 0.6252 - accuracy: 0.6756 - val_loss: 0.4665 - val_accuracy: 0.7209
# Epoch 2/80
# 11/11 [==============================] - 0s 7ms/step - loss: 0.5228 - accuracy: 0.7516 - val_loss: 0.4233 - val_accuracy: 0.7674
# Epoch 3/80
# 11/11 [==============================] - 0s 6ms/step - loss: 0.4634 - accuracy: 0.8442 - val_loss: 0.3756 - val_accuracy: 0.9302
# Epoch 4/80
# 11/11 [==============================] - 0s 6ms/step - loss: 0.4000 - accuracy: 0.8652 - val_loss: 0.3321 - val_accuracy: 0.9767
# Epoch 5/80
# 11/11 [==============================] - 0s 6ms/step - loss: 0.3709 - accuracy: 0.8596 - val_loss: 0.2929 - val_accuracy: 0.9535
# Epoch 6/80
# 11/11 [==============================] - 0s 6ms/step - loss: 0.3364 - accuracy: 0.9035 - val_loss: 0.2611 - val_accuracy: 0.9767
# Epoch 7/80
# 11/11 [==============================] - 0s 6ms/step - loss: 0.3410 - accuracy: 0.8583 - val_loss: 0.2442 - val_accuracy: 0.9767
# Epoch 8/80
# 11/11 [==============================] - 0s 6ms/step - loss: 0.2673 - accuracy: 0.9295 - val_loss: 0.2077 - val_accuracy: 0.9767
# Epoch 9/80
# 11/11 [==============================] - 0s 6ms/step - loss: 0.2579 - accuracy: 0.9083 - val_loss: 0.1899 - val_accuracy: 0.9767
# Epoch 10/80
# 11/11 [==============================] - 0s 7ms/step - loss: 0.2579 - accuracy: 0.9166 - val_loss: 0.1769 - val_accuracy: 0.9767
# Epoch 11/80
# 11/11 [==============================] - 0s 6ms/step - loss: 0.2265 - accuracy: 0.9127 - val_loss: 0.1646 - val_accuracy: 0.9767
# Epoch 12/80
# 11/11 [==============================] - 0s 7ms/step - loss: 0.1760 - accuracy: 0.9461 - val_loss: 0.1601 - val_accuracy: 0.9767
# Epoch 13/80
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1914 - accuracy: 0.9368 - val_loss: 0.1519 - val_accuracy: 0.9767
# Epoch 14/80
# 11/11 [==============================] - 0s 7ms/step - loss: 0.1747 - accuracy: 0.9380 - val_loss: 0.1481 - val_accuracy: 0.9767
# Epoch 15/80
# 11/11 [==============================] - 0s 6ms/step - loss: 0.
80
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0376 - accuracy: 0.9784 - val_loss: 0.0927 - val_accuracy: 0.9767
# Epoch 47/80
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0484 - accuracy: 0.9805 - val_loss: 0.0799 - val_accuracy: 0.9767
# Epoch 48/80
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0545 - accuracy: 0.9788 - val_loss: 0.0724 - val_accuracy: 0.9767
# Epoch 49/80
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0383 - accuracy: 0.9929 - val_loss: 0.0650 - val_accuracy: 0.9767
# Epoch 50/80
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0536 - accuracy: 0.9916 - val_loss: 0.0768 - val_accuracy: 0.9767
# Epoch 51/80
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0440 - accuracy: 0.9828 - val_loss: 0.0900 - val_accuracy: 0.9767
# Epoch 52/80
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0679 - accuracy: 0.9834 - val_loss: 0.0690 - val_accuracy: 0.9767
# Epoch 53/80
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0308 - accuracy: 0.9958 - val_loss: 0.0691 - val_accuracy: 0.9767
# Epoch 54/80
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0258 - accuracy: 0.9985 - val_loss: 0.0632 - val_accuracy: 0.9767
# Epoch 55/80
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0300 - accuracy: 0.9944 - val_loss: 0.0667 - val_accuracy: 0.9767
# Epoch 56/80
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0290 - accuracy: 0.9898 - val_loss: 0.0604 - val_accuracy: 0.9767
# Epoch 57/80
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0226 - accuracy: 0.9885 - val_loss: 0.0473 - val_accuracy: 0.9767
# Epoch 58/80
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0210 - accuracy: 0.9874 - val_loss: 0.0437 - val_accuracy: 0.9767
# Epoch 59/80
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0275 - accuracy: 0.9911 - val_loss: 0.0419 - val_accuracy: 1.0000
# Epoch 60/80
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0392 - accuracy: 0.9921 - val_loss: 0.0449 - val_accuracy: 0.9535
# Epoch 61/80
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0262 - accuracy: 1.0000 - val_loss: 0.0592 - val_accuracy: 0.9767
# Epoch 62/80
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0286 - accuracy: 0.9933 - val_loss: 0.0635 - val_accuracy: 0.9767
# Epoch 63/80
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0263 - accuracy: 0.9906 - val_loss: 0.0443 - val_accuracy: 0.9767
# Epoch 64/80
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0185 - accuracy: 0.9973 - val_loss: 0.0490 - val_accuracy: 0.9767
# Epoch 65/80
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0139 - accuracy: 1.0000 - val_loss: 0.0431 - val_accuracy: 0.9535
# Epoch 66/80
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0225 - accuracy: 0.9946 - val_loss: 0.0578 - val_accuracy: 0.9767
# Epoch 67/80
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0154 - accuracy: 0.9916 - val_loss: 0.0515 - val_accuracy: 0.9767
# Epoch 68/80
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0098 - accuracy: 1.0000 - val_loss: 0.0634 - val_accuracy: 0.9767
# Epoch 69/80
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0142 - accuracy: 0.9973 - val_loss: 0.0642 - val_accuracy: 0.9767
# Epoch 70/80
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0096 - accuracy: 0.9965 - val_loss: 0.0681 - val_accuracy: 0.9767
# Epoch 71/80
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0111 - accuracy: 0.9985 - val_loss: 0.0526 - val_accuracy: 0.9767
# Epoch 72/80
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0307 - accuracy: 0.9862 - val_loss: 0.0785 - val_accuracy: 0.9767
# Epoch 73/80
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0414 - accuracy: 0.9916 - val_loss: 0.0430 - val_accuracy: 0.9767
# Epoch 74/80
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0168 - accuracy: 0.9956 - val_loss: 0.0443 - val_accuracy: 0.9767
# Epoch 75/80
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.0465 - val_accuracy: 0.9535
# Epoch 76/80
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0228 - accuracy: 1.0000 - val_loss: 0.0413 - val_accuracy: 0.9767
# Epoch 77/80
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0149 - accuracy: 0.9985 - val_loss: 0.0457 - val_accuracy: 0.9767
# Epoch 78/80
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0163 - accuracy: 1.0000 - val_loss: 0.0636 - val_accuracy: 0.9767
# Epoch 79/80
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.0735 - val_accuracy: 0.9767
# Epoch 80/80
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0201 - accuracy: 0.9849 - val_loss: 0.0522 - val_accuracy: 0.9767

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
import matplotlib.pyplot as plt

history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']

epochs =  range(1, len(history_dict['accuracy']) + 1)
plt.plot(epochs, loss_values, 'bo', label='Training loss')
plt.plot(epochs, val_loss_values, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc_values = history_dict['accuracy']
val_acc_values = history_dict['val_accuracy']
plt.plot(epochs, acc_values, 'bo', label='Training acc')
plt.plot(epochs, val_acc_values, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
model.evaluate(test_data, test_label)
# Out:
# 5/5 [==============================] - 0s 2ms/step - loss: 0.3214 - accuracy: 0.9357
# [0.3213837146759033, 0.9357143044471741]

# %%
predictions=model.predict(test_data)

# %%
y_pred = (predictions > 0.5)

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(test_label, y_pred))
# Out:
# [[47  8]
#  [ 1 84]]
